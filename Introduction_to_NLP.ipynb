# %% [markdown]
# <a href="https://colab.research.google.com/github/Anik-Adnan/Natural-Language-Processing-NLP/blob/main/Introduction_to_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot From 2025-12-17 14-22-30.png](![Screenshot From 2025-12-17 14-22-30.png](data:image/png;base64,...))

# %% [markdown]
# #Lexical Processing:
# Converts raw text into words/tokens and normalizes them (e.g., cat = cats). Useful for simple tasks like spam detection but ignores word order and structure.
#
# #Syntactic Processing:
# Analyzes grammar and sentence structure to understand roles like subject and object, helping distinguish meanings based on word order.
#
# #Semantic Processing:
# Understands meaning, context, and relationships between words (e.g., PM = Prime Minister, King–Queen–Monarch). Essential for advanced NLP tasks like translation and chatbots.

# %% [markdown]
# # **Deep learning models** automatically learn meaning from data, so explicit, hand-crafted **semantic processing is not needed**, while l**exical input and structure are still implicitly used**.

# %% [markdown]
# ![nlp-working.webp](data:image/webp;base64,...)![NLP-pipeline-steps.png](data:image/png;base64,...)![NLP-3-steps.png](data:image/png;base64,...)

# %% [markdown]
# ## 🧠 Natural Language Processing (NLP) Pipeline
#
# ### 1. Input Text
# Raw, unstructured text collected from sources such as social media, emails, news articles, or documents.
#
# ### 2. Preprocessing
# Cleans and standardizes text to improve model understanding.
# - Tokenization
# - Lowercasing
# - Stop-word removal
# - Stemming / Lemmatization
#
# ### 3. Feature Extraction
# Transforms text into numerical representations.
# - Bag of Words (BoW)
# - TF-IDF
# - Word Embeddings (Word2Vec, GloVe)
#
# ### 4. Modeling
# Applies machine learning or deep learning algorithms to learn patterns.
# - Algorithms: Naive Bayes, SVM, Neural Networks (BERT, GPT)
#
# ### 5. Prediction / Output
# Generates results for new, unseen text.
# - Sentiment Analysis
# - Spam Detection
# - Translation
# - Text Summarization

# %% [markdown]
# # **Text-Encoding**

# %% [markdown]
# # Text Encoding in NLP
#
# ## Why Encoding Matters
# Computers store only numbers, so text characters must be converted into numeric form using encoding before processing.
#
# ## Encoding Standards
# - ASCII
#   Supports only English characters and is now outdated.
#
# - Unicode
#   A universal standard supporting most world languages.
#   - UTF-8: Uses variable length encoding and is memory efficient for English text.
#   - UTF-16: Uses fixed length encoding and is better for many non-English characters.
#
# ## UTF-8 vs UTF-16
# - English and ASCII characters: UTF-8 uses less memory
# - Non-ASCII characters: UTF-16 may use memory more efficiently
#
# ## Python and Encoding
# - Default encoding in Python is UTF-8
# - Text operations:
#   - Encode: convert string to bytes
#   - Decode: convert bytes back to string
#
# ## Key Takeaway
# Understanding text encoding is essential for multilingual NLP tasks.
# Always check the encoding format before processing text.

# %%
# create a string
amount = u"₹50"
print('Default string: ', amount, '\n', 'Type of string', type(amount), '\n')

# encode to UTF-8 byte format
amount_encoded = amount.encode('utf-8')
print('Encoded to UTF-8: ', amount_encoded, '\n', 'Type of string', type(amount_encoded), '\n')


# sometime later in another computer...
# decode from UTF-8 byte format
amount_decoded = amount_encoded.decode('utf-8')
print('Decoded from UTF-8: ', amount_decoded, '\n', 'Type of string', type(amount_decoded), '\n')
# Out:
# Default string:  ₹50
#  Type of string <class 'str'>
#
# Encoded to UTF-8:  b'\xe2\x82\xb950'
#  Type of string <class 'bytes'>
#
# Decoded from UTF-8:  ₹50
#  Type of string <class 'str'>

# %% [markdown]
# # Regular Expressions (Regex) — Introduction
#
# ## What is a Regular Expression?
# A **regular expression (regex)** is a sequence of characters that defines a **pattern**.
# It is used to **find, extract, substitute, or manipulate** substrings in a text.
#
# ## Why Regex is Important
# - Extract **hashtags** from tweets (`#mumbai`, `#bangalore`, etc.)
# - Extract **phone numbers** or other patterns from text
# - Perform **string replacements** and other text manipulations
#
# ## Key Points
# - Regex allows you to **identify patterns** in text efficiently.
# - Regex has its own syntax and compiler.
# - Supported by almost all popular programming languages, including Python.
#
# ## Regex in Python
# - Use the `re` module for regular expressions.
# - `re.search(pattern, string)`:
#   - Returns a **RegexObject** if the pattern is found.
#   - Returns **None** if the pattern is not found.
# - `'match string'` and `'extract string'` are used interchangeably in practice problems.
#
# ## Practice Notes
# - Write code using `re.search()` to detect patterns.
# - Verify your code using the **Verify** button.
# - Check sample solutions after submitting if needed.

# %% [markdown]
# # Question 1: Check Presence of 'education'
#
# **Description:**
# Check whether the word `'education'` is present in the sentence:
# *"The roots of education are bitter, but the fruit is sweet."*
# Use `re.search()` to return `True` if present, else `False`.

# %%
# Question 1: Python Code
import re

string = 'The roots of education are bitter, but the fruit is sweet.'

# regex pattern to check if 'education' is present
pattern = 'education'

# check whether pattern is present in string or not
result = re.search(pattern, string)

if result != None:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# # Question 2: Extract Start Position
#
# **Description:**
# Extract the **starting position** of the word `'education'` in the sentence using `result.start()`.

# %%
# Question 2: Python Code
import re

string = 'The roots of education are bitter, but the fruit is sweet.'

pattern = 'education'

result = re.search(pattern, string)

# get starting position of the match
start_position = result.start()

print(start_position)
# Out:
# 13

# %% [markdown]
# # Question 3: Extract End Position
#
# **Description:**
# Extract the **ending position** of the word `'education'` in the sentence using `result.end()`.

# %%
# Question 3: Python Code
import re

string = 'The roots of education are bitter, but the fruit is sweet.'

pattern = 'education'

result = re.search(pattern, string)

# get ending position of the match
end_position = result.end()

print(end_position)
# Out:
# 22

# %% [markdown]
# # Regular Expressions — Quantifiers
#
# ## Recap
# - `re.search()` returns a **RegexObject** if the pattern is found; else `None`.
# - `match.start()` → starting index of the match
# - `match.end()` → ending index of the match
# - Other functions in the `re` library exist for various tasks.
#
# ## Introduction to Quantifiers
# Quantifiers let you control **how many times a character or group appears** in a pattern.
#
# ### Example
# Suppose you have a list of words:

# %% [markdown]
# # Regex Exercise — Match 'tree' or 'trees'
#
# **Description:**
# Write a regular expression that matches the word `'tree'` or `'trees'` in a given text.
#
# **Sample positive cases:**
# - 'The tree stands tall.'
# - 'There are a lot of trees in the forest.'
#
# **Sample negative cases:**
# - 'The boy is heading for the school.'
# - 'It's really hot outside!'

# %%
# Python Code
import sys
import re

# read input string
string = sys.stdin.read()

# regex pattern to match 'tree' or 'trees'
pattern = r'trees?'  # 's?' means optional 's'

# check whether pattern is present in string
result = re.search(pattern, string)

# evaluate result
if result != None:
    print(True)
else:
    print(False)
# Out:
# False

# %% [markdown]
# # Regex Exercise — Match 'x', 'xy', 'xz', 'xyz'
#
# **Description:**
# Write a regular expression that matches the following words:
# - `x`
# - `xy`
# - `xz`
# - `xyz`
#
# Do **not** match:
# - `Xyyz`, `Xyzz`, `Xyy`, `Xzz`, `Yz`

# %%
# Python Code
import re

# input string (replace with test string)
string = 'xyz'  # Example: change to 'x', 'xy', 'xz', etc. for testing

# regex pattern to match 'x', 'xy', 'xz', 'xyz' only
pattern = r'x(y)?(z)?$'

# check whether pattern is present in string
result = re.search(pattern, string)

# evaluate result
if result != None:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# # Question 1: Binary Number Starting with 101
#
# **Description:**
# Match a binary number that **starts with `101`** and ends with **zero or more zeros**.
#
# **Sample positive cases:**
# - 1010
# - 10100
# - 101000
# - 101
#
# **Sample negative cases:**
# - 10
# - 100
# - 1

# %%
# Question 1: Python Code
import re

# input string (replace with test string)
string = '10100'  # test any example

# regex pattern: starts with 101, followed by zero or more 0's
pattern = r'^1010*$'

# check pattern
result = re.search(pattern, string)

if result != None:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# # Question 2: Binary Number Starting with 1 and Ending with 0
#
# **Description:**
# Write a pattern that **starts with 1**, ends with **0**, and has **zero or more 1s in between**.
#
# **Sample positive cases:**
# - 110
# - 11111110
# - 10
#
# **Sample negative cases:**
# - 11
# - 00
# - 1
# - 0

# %%
# Question 2: Python Code
import re

# input string (replace with test string)
string = '11111110'  # test any example

# regex pattern: starts with 1, zero or more 1's, ends with 0
pattern = r'^1[1]*0$'

# check pattern
result = re.search(pattern, string)

if result != None:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# # Regular Expressions — Quantifiers II
#
# ## Recap of Previous Quantifiers
# - `?` → Matches the preceding character **0 or 1 time** (optional)
# - `*` → Matches the preceding character **0 or more times**
# - `+` → Matches the preceding character **1 or more times** (at least once)
#
# **Difference between `*` and `+`:**
# - `*` → character may be absent
# - `+` → character must appear at least once
#
# ## Fixed-Occurrence Quantifiers
# Sometimes you need to match a character **exactly** a number of times or within a range:
#
# 1. `{m, n}` → Matches the preceding character **m to n times**
# 2. `{m,}` → Matches the preceding character **m to infinite times**
# 3. `{, n}` → Matches the preceding character **0 to n times**
# 4. `{n}` → Matches the preceding character **exactly n times**
#
# **Notes:**
# - Avoid spaces inside `{m,n}` → write `{m,n}` not `{m, n}`
# - These can **replace other quantifiers**:
#   - `?` ≡ `{0,1}`
#   - `*` ≡ `{0,}`
#   - `+` ≡ `{1,}`

# %% [markdown]
# # Regex Exercises — Quantifiers and Patterns

# %% [markdown]
# ## Question 1: Match 'ab+' against 'ac'
#
# **Description:**
# Check whether the pattern `'ab+'` matches the string `'ac'`.

# %%
import re

string = "ac"
pattern = "ab+"

result = re.search(pattern, string)

if result != None:
    print(True)
else:
    print(False)
# Out:
# False

# %% [markdown]
# ## Question 2: Match numbers that are powers of 10
#
# **Positive:** 10, 100, 1000
# **Negative:** 0, 1, 15

# %%
import re

# Test string
string = "1000"  # replace with input string

# Pattern: 1 followed by one or more 0s
pattern = r'^10+$'

result = re.search(pattern, string)

if result != None:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# ## Question 3: Which string will not match 'abc+d'?
#
# **Pattern:** `abc+d`
# **Strings:**
# - abcd ✅
# - abccd ✅
# - abd ❌
# - abccccccccd ✅
#
# **Answer:** `abd` will not match.

# %% [markdown]
# ## Question 4: '?' quantifier equivalent
#
# **Answer:** `{0,1}` ✅

# %% [markdown]
# ## Question 5: Match 'hurray' with 2-5 'r's
#
# **Pattern:** `hurr{2,5}ay`

# %%
import re

string = "hurrray"  # test string

pattern = r'hurr{2,5}ay'

result = re.search(pattern, string)

if result != None:
    print(True)
else:
    print(False)

# %% [markdown]
# ## Question 6: Match 'awesome' with more than 2 'e's at the end
#
# **Pattern:** `awesome{3,}`

# %%
import re

string = "awesomeeee"  # test string

pattern = r'awesome{3,}'

result = re.search(pattern, string)

if result != None:
    print(True)
else:
    print(False)

# %% [markdown]
# ## Question 7: Match 'a' followed by 'b' a maximum of 3 times
#
# **Pattern:** `ab{0,3}`

# %%
import re

string = "abbb"  # test string

pattern = r'ab{0,3}'

result = re.search(pattern, string)

if result != None:
    print(True)
else:
    print(False)

# %% [markdown]
# ## Question 8: Match three or more '0's followed by one or more '1's
#
# **Pattern:** `0{3,}1+`

# %%
import re

string = "0001111"  # test string

pattern = r'0{3,}1+'

result = re.search(pattern, string)

if result != None:
    print(True)
else:
    print(False)

# %% [markdown]
# # Regex Comprehension Exercises
#
# ## 1. Whitespace in Regex
# - Whitespace includes spaces, tabs (`\t`) or newlines (`\n`)
# - Example: `"James Allen"` matches exactly that name including the space
# - `" +"` matches **one or more spaces**

# %% [markdown]
# ## 2. Grouping with Parentheses
# - `(abc){1,3}` → Matches `abc`, `abcabc`, `abcabcabc`
# - `(010)+` → Matches `010`, `010010`, `010010010`, …
# - Parentheses allow quantifiers to repeat **groups of characters**

# %%
import re
import sys

string = sys.stdin.read()

# Match '23' one or more times followed by '78' one or more times
pattern = r'(23)+?(78)+'

result = re.search(pattern, string)
print(result != None)
# Out:
# False

# %% [markdown]
# ## 3. Pipe Operator `|` (OR)
# - `(d|g)one` → matches `done` or `gone`
# - `(ICICI|HDFC) Bank` → matches `ICICI Bank` or `HDFC Bank`
# - Multiple pipes: `(0|1|2){2}` → matches any two-digit string composed of 0,1,2

# %%
import re
import sys

string = sys.stdin.read()

# Match Basketball, Baseball, Volleyball, Softball, Football
pattern = r'(Basketball|Baseball|Volleyball|Softball|Football)'

result = re.search(pattern, string)
print(result != None)
# Out:
# False

# %% [markdown]
# ## 4. Escaping Special Characters
# - `?`, `*`, `+`, `(`, `)`, `{` are special characters in regex
# - Escape them with `\` to match **literally**
# - Example:
#   - `\?` → matches literal question mark
#   - `\+` → matches literal plus
#   - `\(78\)` → matches literal `(78)`

# %%
import re
import sys

string = sys.stdin.read()

# Match multiplication equations containing '*'
pattern = r'\*'

result = re.search(pattern, string)
print(result != None)
# Out:
# False

# %% [markdown]
# ## 5. Regex Flags
# - `re.I` → Ignore case
# - `re.M` → Multi-line search
# - Multiple flags: `flags = re.I | re.M`
#
# Example:
# ```python
# re.search(pattern, string, flags=re.I | re.M)

# %% [markdown]
# ---
#
# ```markdown
# ## 6. Using re.compile()
# - Compiles regex into a **pattern object** for faster repeated searches
# - Without compile:
# ```python
# result = re.search("a+", "abc")

# %%
pattern = re.compile("a+")
result = pattern.search("abc")

# %% [markdown]
# ---
#
# This Markdown + Python code gives you:
#
# - Whitespace handling
# - Grouping with quantifiers
# - Pipe operator usage
# - Escaping special characters
# - Flags (`re.I`, `re.M`)
# - `re.compile()` optimization
#
# ---
#
# If you want, I can **combine all the exercises from Quantifiers I & II and Comprehension into a single **interactive Colab notebook** with ready-to-run examples and test cases**.
#
# Do you want me to do that?

# %% [markdown]
# ### Summary: Regular Expressions – Use Cases
#
# • Regular expressions are powerful tools for searching, filtering, and extracting patterns from text data.
# • They are commonly used to identify specific file types, such as extracting image files based on extensions like `.jpg`.
# • Special characters (e.g., `.`) must be escaped using a backslash (`\`) to match them literally.
# • Regex patterns can be refined to match filenames with specific prefixes and suffixes.
# • Beyond file handling, regex is widely used for extracting dates, emails, phone numbers, and other structured data.
# • Regular expressions play a crucial role in real-world applications such as password validation, username validation, and text processing in NLP.
# • Online regex testing tools help developers write, debug, and validate complex regular expressions efficiently.
